# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(tf.__version__)
print(tf.config.experimental.list_physical_devices('GPU'))
# Out:
# 2.10.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.__version__
# Out:
# '2.10.0'

# %%
#For Data Augmentation Porpuses 
myDataGen_train=ImageDataGenerator(rescale = 1./255.,
                                   rotation_range = 80,
                                   width_shift_range = 0.2,
                                   height_shift_range = 0.2,
                                   shear_range = 0.2,
                                   zoom_range = 0.3,
                                   horizontal_flip = True 
                                   )
myDataGen_test=ImageDataGenerator(rescale = 1./255.)

# %%
import os

# %%
training_dir=os.path.join(os.getcwd(),"./archive/train")
test_dir=os.path.join(os.getcwd(),"./archive/test")
print(os.listdir(training_dir))
print(os.listdir(test_dir))
# Out:
# ['18-20', '21-30', '31-40', '41-50', '51-60']
# ['18-20', '21-30', '31-40', '41-50', '51-60']

# %%
train_ds=myDataGen_train.flow_from_directory(training_dir,class_mode="categorical",target_size=(400,400))
test_ds=myDataGen_test.flow_from_directory(test_dir,class_mode="categorical",target_size=(400,400))
# Out:
# Found 125 images belonging to 5 classes.
# Found 25 images belonging to 5 classes.

# %%
from tensorflow.keras.applications import InceptionV3
#Definition of The Model Using
#In this case we will use the Inception V3 Model

pre_trained_model=InceptionV3(input_shape=(400,400,3),
                            include_top=False,
                            weights=None)

# %%
model_weights=os.path.join(os.getcwd(),"./weightsNN","inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5")

pre_trained_model.load_weights(model_weights)

# %%
#Lest dive into the model a little bit
for layer in pre_trained_model.layers:
    #print(layer.trainable)
    layer.trainable=False

pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 400, 400, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 199, 199, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 199, 199, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 199, 199, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 197, 197, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 197, 197, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
last_usable_layer=pre_trained_model.get_layer("mixed7")

last_output=last_usable_layer.output

# %%
from keras.layers import Flatten,Dense,Dropout
from keras import Model
from keras.optimizers import Adam

x=Flatten()(last_output)
x=Dense(1024,activation="relu")(x)
x=Dropout(0.2)(x)
x=Dense(1024,activation="relu")(x)
x=Dense(1024,activation="relu")(x)
x=Dense(5,activation="softmax")(x)

final_model=Model(pre_trained_model.input,x)
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 400, 400, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 199, 199, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 199, 199, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 199, 199, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 197, 197, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 197, 197, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
final_model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Carrera main\Cursos externos\TFVSCODE\TFCERTIFICATE\CNNS_AND_DNNS\DetectAges.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Carrera%20main/Cursos%20externos/TFVSCODE/TFCERTIFICATE/CNNS_AND_DNNS/DetectAges.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> final_model.compile(loss="categorical_crossentropy", optimizer="sdg", metrics=["accuracy"])
#
# File c:\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ----------
# absl-py                      2.0.0
# appnope                      0.1.3
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.3.2
# certifi                      2023.11.17
# charset-normalizer           3.3.2
# comm                         0.2.0
# debugpy                      1.8.0
# decorator                    5.1.1
# exceptiongroup               1.2.0
# executing                    2.0.1
# flatbuffers                  23.5.26
# gast                         0.5.4
# google-auth                  2.23.4
# google-auth-oauthlib         1.1.0
# google-pasta                 0.2.0
# grpcio                       1.59.3
# h5py                         3.10.0
# idna                         3.6
# ipykernel                    6.26.0
# ipython                      8.18.0
# jedi                         0.19.1
# jupyter_client               8.6.0
# ...

# %%
import sys
import PIL as pl
import scipy
print(pl.__version__)
history=final_model.fit(train_ds,validation_data=test_ds,epochs=20,verbose=2)
# Out:
# 8.4.0
# Epoch 1/20
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# e:\Carrera main\Cursos externos\TFVSCODE\TFCERTIFICATE\CNNS_AND_DNNS\DetectAges.ipynb Cell 14 line 5
#       <a href='vscode-notebook-cell:/e%3A/Carrera%20main/Cursos%20externos/TFVSCODE/TFCERTIFICATE/CNNS_AND_DNNS/DetectAges.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> import scipy
#       <a href='vscode-notebook-cell:/e%3A/Carrera%20main/Cursos%20externos/TFVSCODE/TFCERTIFICATE/CNNS_AND_DNNS/DetectAges.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> print(pl.__version__)
# ----> <a href='vscode-notebook-cell:/e%3A/Carrera%20main/Cursos%20externos/TFVSCODE/TFCERTIFICATE/CNNS_AND_DNNS/DetectAges.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> history=final_model.fit(train_ds,validation_data=test_ds,epochs=20,verbose=2)
#
# ...
